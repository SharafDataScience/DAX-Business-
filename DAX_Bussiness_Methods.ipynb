# %% [markdown]
# - Data validation:
#    - The dataset: 15,000 rows and 8 columns.
#    - week: (int64) Represents the week since product launch. Contains no missing values.
#    - sales_method: (object) Specifies the sales method used: Email, Call, or Email + Call.        Contains no missing values.
#    - customer_id: (object) Unique identifier for each customer. Contains no missing values.
#    - nb_sold: (int64) Number of products sold to the customer. Contains no missing values.
#    - revenue: (float64) Revenue generated from sales, rounded to two decimal places. Contains      missing values (1074 out of 15,000 rows are missing values).
#    - years_as_customer: (int64) Number of years the customer has been buying from the              company, Contains no missing values.
#    - nb_site_visits: (int64) Number of times the customer visited the website in the last 6        months. Contains no missing values.
#    - state: (object) Indicates the shipping location of the customer. Contains no missing          values.
#   - Initial Observations
#   - The revenue column contains 1,074 missing values.
#   - All other columns are complete and contain appropriate data types.
#   - Key numeric fields (nb_sold, revenue, years_as_customer, nb_site_visits) appear           consistent.
#   - cleaning just missing values 1074 in revenue column.
#   - replace 'email' to 'Email' and 'em + call' to 'Email + Call'in sales_method column.
#
#
# - Exploratory Analysis:
#   - Analyze Histogram distributions of revenue and state showing single variable:
#    ![image.png](data:image/png;base64,...)
#
#    ![image.png](data:image/png;base64,...)
#
#   -  Analyze Bar plot of revenue and Sales_method showing two or more variables :
#   ![image.png](data:image/png;base64,...)
#
#
# - Describe your findings:
#   - The histogram of revenue indicates a right-skewed distribution, with the most frequent        revenue values clustering around 50. Additionally, the data shows the presence of      outliers, and The most frequent state is California, while the minimum is Wyoming.
#   - In the bar plot, we can see that the most dominant sales method is a combination of Email and Call, which surpasses Email alone. The least dominant method is Call by itself.
#
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#     - Track Sales Conversion by Sales Method:
#       Monitor how each sales method (Email, Call, or Email + Call) contributes to the overall  sales.
# Calculate the conversion rate for each method, defined as the ratio of the number of sales made via each method to the total number of interactions (visits).
# Use this metric to understand which sales method is the most effective in driving revenue and generating leads.
#     - Identify Areas for Improvement:Use the metric to identify which sales methods are underperforming relative to others.
# Investigate potential reasons for low conversion efficiency, such as the need for training, changes in the sales approach, or website usability issues.
# Adjust sales strategies accordingly to optimize conversion rates.
#     - Optimize Sales Strategies: Based on the conversion efficiency, optimize sales strategies and allocate resources more effectively. For instance, if 'Email + Call' shows the highest conversion efficiency, prioritize this method in terms of training, incentives, and marketing efforts. Conversely, if 'Call' shows a low conversion rate, consider testing alternative strategies or combining it with another method to enhance its effectiveness.
#
#   - Can you estimate initial value(s) for the metric based on the current data
#      - Current Data Observations: The dataset contains 15,000 rows and 8 columns,There are 1,074 missing values in the revenue column, The most frequent sales method is 'Email + Call', followed by 'Email' alone and 'Call', California is the most frequent state, Revenue data shows a right-skewed distribution with most values clustering around 50.
#
# - Final Recommendations:
#   - Enhance Data Quality: Improve data collection processes to minimize missing values and inconsistencies in columns.
# Use predictive methods to fill in gaps in the revenue column.
# Target Sales Strategy:
#
#   - Focus on the most effective sales method ('Email + Call') to maximize conversion rates. Evaluate the training needs and potential improvements in other methods like 'Call' to enhance their effectiveness. Consider regional differences in sales methods and tailor strategies accordingly, especially targeting high-density states like California.
#   - Optimize Marketing and Sales Resources: Based on the conversion rates, allocate marketing and sales resources effectively. Increase focus on the most effective methods and reduce efforts on methods that are not performing as well. Experiment with combining sales methods further, such as integrating 'Email + Call' with other digital or in-person strategies to explore additional synergies.
#   - Regular Monitoring and Adjustment: Establish a system for regular monitoring of sales conversion rates by method to track changes over time.
# Adjust strategies promptly based on metric changes and business needs to optimize sales performance continuously.

# %%
import numpy as np
import pandas as pd
import warnings
import io
from google.colab import files
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Upload the file
uploaded = files.upload()
# Assuming the file you uploaded is 'product.csv'
filename = list(uploaded.keys())[0]  # get the uploaded file name
# Read the uploaded file into a pandas DataFrame
df_raw = pd.read_csv(io.BytesIO(uploaded[filename]))
# Out:
#      <input type="file" id="files-2d8514b2-f41e-4e72-86c5-11c68fcf99f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d8514b2-f41e-4e72-86c5-11c68fcf99f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Data validation:

# %%
# Display the first few rows of the DataFrame
df_raw.tail(20)
# Out:
#        week  sales_method                           customer_id  nb_sold  \
# 14980     3          Call  788bfaaa-56a9-4f7b-82c8-c0f65760ef54        8
# 14981     6          Call  50608b92-2045-4851-be63-282f956660fa       14
# 14982     5  Email + Call  dde667d0-e963-4a2e-a1b7-f2f341a0d245       13
# 14983     1  Email + Call  bec6d233-f7ad-401f-9c2e-54fed5ce2937        9
# 14984     4  Email + Call  e599ac4d-4634-49a6-b373-04c021d3a1ab       12
# 14985     3  Email + Call  86756cf2-5ad6-4fc8-8d65-557e4c946174       10
# 14986     3          Call  aaa8e5b8-a334-43a8-a55f-fe6197300e93        9
# 14987     1         Email  bb4b9fb0-f704-4da5-bc1c-6c3545860430       10
# 14988     2          Call  b6e0a974-616c-442c-b976-f36f5b3ef757        9
# 14989     2         Email  8c9138d0-690b-4709-a279-5e0d4c6429d0       10
# 14990     2          Call  b8e19654-e5a1-4094-aaa7-99a9821f9c06        9
# 14991     2  Email + Call  b5c6d6e0-1237-4785-b088-17064d44d366       10
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               15000 non-null  int64
#  1   sales_method       15000 non-null  object
#  2   customer_id        15000 non-null  object
#  3   nb_sold            15000 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  15000 non-null  int64
#  6   nb_site_visits     15000 non-null  int64
#  7   state              15000 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %%
df_raw.shape
# Out:
# (15000, 8)

# %%
df_raw.describe()
# Out:
#                week       nb_sold       revenue  years_as_customer  \
# count  15000.000000  15000.000000  13926.000000       15000.000000
# mean       3.098267     10.084667     93.934943           4.965933
# std        1.656420      1.812213     47.435312           5.044952
# min        1.000000      7.000000     32.540000           0.000000
# 25%        2.000000      9.000000     52.470000           1.000000
# 50%        3.000000     10.000000     89.500000           3.000000
# 75%        5.000000     11.000000    107.327500           7.000000
# max        6.000000     16.000000    238.320000          63.000000
#
#        nb_site_visits
# count    15000.000000
# mean        24.990867
# std          3.500914
# min         12.000000
# 25%         23.000000
# 50%         25.000000
# 75%         27.000000
# max         41.000000

# %%
# function to count missing data and in which feature.
def missing_data(data):
    nb_values = data.isnull().sum().sort_values(ascending = False) #contains the number of values missing
    percent_values = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False) #contains the percentage of values missing
    return pd.concat([nb_values, percent_values], axis=1, keys=['Number of Missing Values', 'Percentage of Missing Values'])

missing_data(df_raw).head(8)
# Out:
#                    Number of Missing Values  Percentage of Missing Values
# revenue                                1074                          7.16
# week                                      0                          0.00
# sales_method                              0                          0.00
# customer_id                               0                          0.00
# nb_sold                                   0                          0.00
# years_as_customer                         0                          0.00
# nb_site_visits                            0                          0.00
# state                                     0                          0.00

# %%
df_clened_missValues = df_raw.dropna()

# %%
missing_data(df_clened_missValues).head(5)
# Out:
#               Number of Missing Values  Percentage of Missing Values
# week                                 0                           0.0
# sales_method                         0                           0.0
# customer_id                          0                           0.0
# nb_sold                              0                           0.0
# revenue                              0                           0.0

# %%
is_unique = df_raw['customer_id'].is_unique

if is_unique:
    print("The 'customer_id' column is a unique identifier.")
else:
    print("The 'customer_id' column is not a unique identifier.")
# Out:
# The 'customer_id' column is a unique identifier.

# %%
salesmethod_counts = df_raw['sales_method'].value_counts()
print(salesmethod_counts )
# Out:
# sales_method
# Email           7456
# Call            4962
# Email + Call    2549
# em + call         23
# email             10
# Name: count, dtype: int64

# %%
df_raw['sales_method'] = df_raw['sales_method'].replace('email','Email')
df_raw['sales_method'] = df_raw['sales_method'].replace('em + call','Email + Call')

# %% [markdown]
# # Exploratory Analysis:

# %%
# Analyze the revenue column to understand its range and detect anomalies
revenue_stats = df_raw['revenue'].describe()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_raw['state'], bins=30, kde=True)
plt.title('Distribution of state')
plt.xlabel('state')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_raw['revenue'], bins=50, kde=True)
plt.title('Distribution of Revenue')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(y='revenue',x='sales_method',data= df_raw)
# Out:
# <Axes: xlabel='sales_method', ylabel='revenue'>
